# %%
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# ### Лабораторная 3
# Решить задачу Коши методом Адамса со значениями шага $h_1 = 0.1$ и $h_2 = 0.01$. Сравнить результаты графически.
#
# **2 вариант**
# $$y' = \frac{y(2y*ln(x-1)-1)}{x}$$
# $$y(1) = 0.33333333$$
# $$x \in [1, 2]$$

# %%
# 2 вариант
def y_diff(x, y): return y * (2 * y * np.log(x) - 2) / x

h = [.1, .01]

x_0, y_0, start, end = 1, 1/3, 1, 2

# %%
def kutta4(y_diff, x:float, y:float, start:float, end:float, h:float) -> list:
    Y = [y]
    for x_i in np.linspace(start, end, 3):
        k_1 = h * y_diff(x_i, Y[-1])
        k_2 = h * y_diff(x_i + h/2, Y[-1] + k_1/2)
        k_3 = h * y_diff(x_i + h/2, Y[-1] + k_2/2)
        k_4 = h * y_diff(x_i + h, Y[-1] + k_3)
        Y.append(Y[-1] + (k_1+2*k_2+2*k_3+k_4)/6)
    return Y

# %% [markdown]
# #### Метод Адамса

# %%
def adams(y_diff, x:float, y:float, start:float, end:float, h:float) -> list:
    Y = kutta4(y_diff, x, y, start, start + h * 2, h)
    for x_i in np.arange(start + h * 3, end, h):
        fk1 = y_diff(x_i, Y[-1])
        fk2 = y_diff(x_i - h, Y[-2])
        fk3 = y_diff(x_i - h * 2, Y[-3])
        fk4 = y_diff(x_i - h * 3, Y[-4])
        Y.append(Y[-1] + h/24 * (55 * fk1 - 59 * fk2 + 37 * fk3 - 9 * fk4))
    return Y

# %%
x_h0 = np.arange(start, end + h[0], h[0])
y_h0 = adams(y_diff, x_0, y_0, start, end, h[0])

x_h1 = np.arange(start, end + h[1], h[1])
y_h1 = adams(y_diff, x_0, y_0, start, end, h[1])

# %% [markdown]
# #### Постороение графика

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=x_h0, y=y_h0, mode='lines', name='h<sub>0</sub> = 0.1'))
fig.add_trace(go.Scatter(x=x_h1, y=y_h1, mode='lines', name='h<sub>1</sub> = 0.01'))
fig.update_layout(legend_orientation = 'h',
                  legend = dict(x=.5, xanchor='center'),
                  title = 'Метод Адамса')
fig.show()
# Out:
# <div>                            <div id="a3fd2e0e-5e2d-4666-8f1c-60cb7b3c6d20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3fd2e0e-5e2d-4666-8f1c-60cb7b3c6d20")) {                    Plotly.newPlot(                        "a3fd2e0e-5e2d-4666-8f1c-60cb7b3c6d20",                        [{"mode":"lines","name":"h<sub>0</sub> = 0.1","x":[1.0,1.1,1.2000000000000002,1.3000000000000003,1.4000000000000004,1.5000000000000004,1.6000000000000005,1.7000000000000006,1.8000000000000007,1.9000000000000008,2.000000000000001],"y":[0.3333333333333333,0.27621978556567167,0.2335186954843581,0.2005072538536699,0.1747517615932663,0.1536395060613162,0.13630023560369575,0.1217147820431254,0.10941684952250723,0.09889609883106615,0.08984860979722153],"type":"scatter"},{"mode":"lines","name":"h<sub>1</sub> = 0.01","x":[1.0,1.01,1.02,1.03,1.04,1.05,1.06,1.07,1.08,1.09,1.1,1.11,1.12,1.1300000000000001,1.1400000000000001,1.1500000000000001,1